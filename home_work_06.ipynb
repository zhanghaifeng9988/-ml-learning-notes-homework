# %% [markdown]
# ### In this homework, we continue using the fuel efficiency dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import  pyplot as plt
# %matplotlib  inline

# %%
# !head car_fuel_efficiency.csv
# Out:
# engine_displacement,num_cylinders,horsepower,vehicle_weight,acceleration,model_year,origin,fuel_type,drivetrain,num_doors,fuel_efficiency_mpg
# 170,3,159,3413.433758606219,17.7,2003,Europe,Gasoline,All-wheel drive,0,13.231728906241411
# 130,5,97,3149.6649342200353,17.8,2007,USA,Gasoline,Front-wheel drive,0,13.688217435463793
# 170,,78,3079.03899736884,15.1,2018,Europe,Gasoline,Front-wheel drive,0,14.246340998160866
# 220,4,,2542.392401828378,20.2,2009,USA,Diesel,All-wheel drive,2,16.91273559598635
# 210,1,140,3460.870989989018,14.4,2009,Europe,Gasoline,All-wheel drive,2,12.488369121964562
# 190,3,,2484.883986036068,14.7,2008,Europe,Gasoline,All-wheel drive,-1,17.271818372724237
# 240,7,127,3006.5422872171457,22.2,2012,USA,Gasoline,Front-wheel drive,1,13.210412112385608
# 150,4,239,3638.6577802809,17.3,2020,USA,Diesel,All-wheel drive,1,12.848883861524026
# 250,1,174,2714.219309645285,10.3,2016,Asia,Diesel,Front-wheel drive,-1,16.823553726916543

# %%
df = pd.read_csv('car_fuel_efficiency.csv')

# %%
df.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                     str
# fuel_type                  str
# drivetrain                 str
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# engine_displacement    0
# num_cylinders          0
# horsepower             0
# vehicle_weight         0
# acceleration           0
# model_year             0
# origin                 0
# fuel_type              0
# drivetrain             0
# num_doors              0
# fuel_efficiency_mpg    0
# dtype: int64

# %%
df.describe()
# Out:
#        engine_displacement  num_cylinders   horsepower  vehicle_weight  \
# count          9704.000000    9222.000000  8996.000000     9704.000000
# mean            199.708368       3.962481   149.657292     3001.280993
# std              49.455319       1.999323    29.879555      497.894860
# min              10.000000       0.000000    37.000000      952.681761
# 25%             170.000000       3.000000   130.000000     2666.248985
# 50%             200.000000       4.000000   149.000000     2993.226296
# 75%             230.000000       5.000000   170.000000     3334.957039
# max             380.000000      13.000000   271.000000     4739.077089
#
#        acceleration   model_year    num_doors  fuel_efficiency_mpg
# count   8774.000000  9704.000000  9202.000000          9704.000000
# mean      15.021928  2011.484027    -0.006412            14.985243
# std        2.510339     6.659808     1.048162             2.556468
# min        6.000000  2000.000000    -4.000000             6.200971
# 25%       13.300000  2006.000000    -1.000000            13.267459
# 50%       15.000000  2012.000000     0.000000            15.006037
# 75%       16.700000  2017.000000     1.000000            16.707965
# max       24.300000  2023.000000     4.000000            25.967222

# %% [markdown]
# ### num_cylinders（气缸数）- 最小值0
# ### num_doors（车门数）- 存在负值
# 下面处理这些异常值

# %%
# 查看num_cylinders中具体有哪些0值
df[df['num_cylinders'] == 0]
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                     170            0.0        78.0     3079.038997
# 45                    380            0.0       139.0     1833.196403
# 87                    240            0.0       179.0     2928.390984
# 98                    250            0.0       109.0     3210.919484
# 105                   310            0.0       103.0     3514.690130
# ...                   ...            ...         ...             ...
# 9662                  280            0.0       153.0     2443.765748
# 9663                  280            0.0       205.0     2145.925045
# 9670                  250            0.0        99.0     2640.310957
# 9689                  260            0.0       166.0     2396.251595
# 9700                  180            0.0       154.0     2439.525729
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 2             15.1        2018  Europe  Gasoline  Front-wheel drive
# 45            16.7        2022     USA  Gasoline  Front-wheel drive
# 87            16.2        2010    Asia    Diesel  Front-wheel drive
# 98            14.6        2021     USA    Diesel    All-wheel drive
# 105           15.7        2011    Asia  Gasoline  Front-wheel drive
# ...            ...         ...     ...       ...                ...
# 9662          16.1        2002  Europe    Diesel  Front-wheel drive
# 9663          12.7        2018    Asia    Diesel    All-wheel drive
# 9670          17.5        2001  Europe  Gasoline  Front-wheel drive
# 9689           0.0        2014  Europe  Gasoline  Front-wheel drive
# 9700          15.0        2004     USA  Gasoline    All-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 2           0.0            14.246341
# 45         -1.0            20.728617
# 87          1.0            15.192541
# 98          0.0            13.128946
# 105         0.0            11.745028
# ...         ...                  ...
# 9662        0.0            17.686575
# 9663        0.0            20.319320
# 9670        1.0            16.187978
# 9689        0.0            18.879329
# 9700        0.0            17.962326
#
# [665 rows x 11 columns]

# %%
# # 用中位数或众数填充
median_cyl = df['num_cylinders'].median()
df['num_cylinders'] = df['num_cylinders'].replace(0, median_cyl)
df[df['num_cylinders'] == 0]
# Out:
# Empty DataFrame
# Columns: [engine_displacement, num_cylinders, horsepower, vehicle_weight, acceleration, model_year, origin, fuel_type, drivetrain, num_doors, fuel_efficiency_mpg]
# Index: []

# %%
# 查看num_doors 异常值得情况
df['num_doors'].value_counts().sort_index()
# Out:
# num_doors
# -4.0       4
# -3.0      56
# -2.0     594
# -1.0    2183
#  0.0    4053
#  1.0    2192
#  2.0     563
#  3.0      58
#  4.0       1
# Name: count, dtype: int64

# %%
# 以上结果，经过分析，我得方案是，将车门数量，作为‘分类特征’

# %%
df.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                     str
# fuel_type                  str
# drivetrain                 str
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
df_full_train,df_test = train_test_split(df, test_size=0.2, random_state=1) 
df_train,df_val = train_test_split(df_full_train, test_size=0.25, random_state=1) 
len(df_full_train),len(df_test),len(df_train),len(df_val)
# Out:
# (7763, 1941, 5822, 1941)

# %%
df_train = df_train.reset_index(drop=True)   #将上面划分数据打乱的索引，重建索引，并删除旧索引
df_val = df_val.reset_index(drop=True) 
df_test = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.fuel_efficiency_mpg.values)
y_val = np.log1p(df_val.fuel_efficiency_mpg.values)
y_test = np.log1p(df_test.fuel_efficiency_mpg.values)

# %%
del df_train['fuel_efficiency_mpg']
del df_val['fuel_efficiency_mpg']
del df_test['fuel_efficiency_mpg']

# %%
from sklearn.feature_extraction  import DictVectorizer

# %%
train_dicts = df_train.to_dict(orient='records')
val_dicts = df_val.to_dict(orient='records')
test_dicts = df_test.to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=True) # 这里使用稀疏矩阵

# %%
X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (5822, 14)

# %%
X_val = dv.transform(val_dicts)

# %%
X_test = dv.transform(test_dicts)

# %% [markdown]
# #  Question 1

# %% [markdown]
# Let's train a decision tree regressor to predict the fuel_efficiency_mpg variable.
#
# Train a model with max_depth=1.
# Which feature is used for splitting the data?
#
# 'vehicle_weight'

# %%
from sklearn.tree import DecisionTreeRegressor  # 决策树，回归模型

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'engine_displacement',
#        'fuel_type=Diesel', 'fuel_type=Gasoline', 'horsepower',
#        'model_year', 'num_cylinders', 'num_doors', 'origin=Asia',
#        'origin=Europe', 'origin=USA', 'vehicle_weight'], dtype=object)

# %%
# 对于 max_depth=1 的决策树（也叫决策树桩，Decision Stump），树只有一个分裂节点，这个节点就是根节点。
dtreg_model = DecisionTreeRegressor(max_depth=1, random_state=42)

# %%
dtreg_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=1, random_state=42)

# %%
feature_index = dtreg_model.tree_.feature[0]  # 根节点的分裂特征索引

# %%
feature_index
# Out:
# np.int64(13)

# %%
feature_name = dv.get_feature_names_out()[feature_index]  # 获取特征名称
feature_name
# Out:
# 'vehicle_weight'

# %% [markdown]
# # Question 2
# Train a random forest regressor with these parameters:
#
# n_estimators=10
# random_state=1
# n_jobs=-1 (optional - to make training faster)
# What's the RMSE of this model on the validation data?
#
# 0.045

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error    # 计算均方误差（Mean Squared Error, MSE）的评估指标函数

# %%
# 1. 创建并训练模型
rf_model = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
# 2. 在验证集上预测
y_pred = rf_model.predict(X_val)
y_pred
# Out:
# array([2.97478978, 2.79263338, 2.95890123, ..., 2.75620826, 2.6900929 ,
#        2.82267273], shape=(1941,))

# %%
# 3. 计算 RMSE（注意：y_val 是 log1p 转换后的值）
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.030221736605120578

# %% [markdown]
# #### 按照这个RMSE值，如果你预测一辆车油耗是 20 MPG，实际可能在 19.4 - 20.6 MPG 之间，预测精度非常高。

# %% [markdown]
# # Question 3
# Now let's experiment with the n_estimators parameter
#
# Try different values of this parameter from 10 to 200 with step 10.
# Set random_state to 1.
# Evaluate the model on the validation dataset.
# After which value of n_estimators does RMSE stop improving? Consider 3 decimal places for calculating the answer.
#
# 80
#
# If it doesn't stop improving, use the latest iteration number in your answer.

# %%
# 存储不同 n_estimators 对应的 RMSE
# 测试的 n_estimators 值
n_values = [10, 25, 80, 200]
rmse_scores = []

for n in n_values:
    # 训练模型
    rf = RandomForestRegressor(n_estimators=n, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)
    
    # 验证集预测
    y_pred = rf.predict(X_val)
    
    # 计算 RMSE
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    rmse_scores.append(rmse)
    
    print(f"n_estimators={n:3d}, RMSE={rmse:.3f}")
# Out:
# n_estimators= 10, RMSE=0.030
# n_estimators= 25, RMSE=0.030
# n_estimators= 80, RMSE=0.029
# n_estimators=200, RMSE=0.029

# %% [markdown]
# # Question 4
# Let's select the best max_depth:
#
# Try different values of max_depth: [10, 15, 20, 25]
# For each of these values,
# try different values of n_estimators from 10 till 200 (with step 10)
# calculate the mean RMSE
# Fix the random seed: random_state=1
# What's the best max_depth, using the mean RMSE?
#
# 10

# %%
max_depth_values = [10, 15, 20, 25]
n_estimators_range = range(10, 201, 10)
for max_depth in max_depth_values:
    rmse_list = []
    
    for n in n_estimators_range:
        rf = RandomForestRegressor(
            n_estimators=n,
            max_depth=max_depth,
            random_state=1,
            n_jobs=-1
        )
        rf.fit(X_train, y_train)
        
        # 验证集预测
        y_pred = rf.predict(X_val)
        
        # 计算 RMSE
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        rmse_list.append(rmse)
    
    # 计算平均 RMSE
    mean_rmse = np.mean(rmse_list)

    print(f"max_depth={max_depth:2d}, 平均 RMSE={mean_rmse:.6f}")
# Out:
# max_depth=10, 平均 RMSE=0.029064
# max_depth=15, 平均 RMSE=0.029232
# max_depth=20, 平均 RMSE=0.029269
# max_depth=25, 平均 RMSE=0.029283

# %% [markdown]
# # Question 5
# We can extract feature importance information from tree-based models.
#
# At each step of the decision tree learning algorithm, it finds the best split. When doing it, we can calculate "gain" - the reduction in impurity before and after the split. This gain is quite useful in understanding what are the important features for tree-based models.
#
# In Scikit-Learn, tree-based models contain this information in the feature_importances_ field.
#
# For this homework question, we'll find the most important feature:
#
# Train the model with these parameters:
# n_estimators=10,
# max_depth=20,
# random_state=1,
# n_jobs=-1 (optional)
# Get the feature importance information from this model
# What's the most important feature (among these 4)?
#
# vehicle_weight

# %%
# 1. 训练模型（使用指定参数）
rf_model = RandomForestRegressor(
    n_estimators=10,
    max_depth=20,
    random_state=1,
    n_jobs=-1
)
rf_model.fit(X_train, y_train)

# 2. 获取特征重要性
feature_importances = rf_model.feature_importances_
feature_names = dv.get_feature_names_out()

# 3. 创建特征重要性 DataFrame 并排序
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importances
})
importance_df = importance_df.sort_values('importance', ascending=False)

# 4. 显示所有特征的重要性
print("所有特征的重要性（从高到低）:")
print(importance_df)

# 5. 只显示题目给出的4个特征
print("\n题目中的4个特征重要性:")
target_features = ['vehicle_weight', 'horsepower', 'acceleration', 'engine_displacement']
for feature in target_features:
    importance = importance_df[importance_df['feature'] == feature]['importance'].values[0]
    print(f"{feature:20s}: {importance:.6f}")

# 6. 找出最重要的特征
most_important = importance_df.iloc[0]['feature']
most_importance = importance_df.iloc[0]['importance']
print(f"\n✅ 最重要的特征: {most_important} (重要性: {most_importance:.6f})")
# Out:
# 所有特征的重要性（从高到低）:
#                          feature  importance
# 13                vehicle_weight    0.958638
# 6                     horsepower    0.016549
# 0                   acceleration    0.011442
# 7                     model_year    0.003423
# 3            engine_displacement    0.003347
# 8                  num_cylinders    0.002062
# 9                      num_doors    0.001603
# 12                    origin=USA    0.000536
# 11                 origin=Europe    0.000470
# 10                   origin=Asia    0.000434
# 5             fuel_type=Gasoline    0.000414
# 2   drivetrain=Front-wheel drive    0.000369
# 4               fuel_type=Diesel    0.000365
# 1     drivetrain=All-wheel drive    0.000349
#
# 题目中的4个特征重要性:
# vehicle_weight      : 0.958638
# horsepower          : 0.016549
# acceleration        : 0.011442
# engine_displacement : 0.003347
#
# ✅ 最重要的特征: vehicle_weight (重要性: 0.958638)

# %% [markdown]
# # Question 6
# Now let's train an XGBoost model! For this question, we'll tune the eta parameter:
#
# Install XGBoost
# Create DMatrix for train and validation
# Create a watchlist
# Train a model with these parameters for 100 rounds:
# xgb_params = {
#     'eta': 0.3,
#     'max_depth': 6,
#     'min_child_weight': 1,
#
#     'objective': 'reg:squarederror',
#     'nthread': 8,
#
#     'seed': 1,
#     'verbosity': 1,
# }
# Now change eta from 0.3 to 0.1.
#
# Which eta leads to the best RMSE score on the validation dataset?
#
# 0.1

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

features = dv.get_feature_names_out().tolist()
print(f"特征数量: {len(features)}")

# 创建 DMatrix（指定 feature_names）
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# 测试不同的 eta
eta_values = [0.3, 0.1]
results = {}

for eta in eta_values:
    print(f"\n训练 eta={eta} 的模型...")
    
    xgb_params = {
        'eta': eta,
        'max_depth': 6,
        'min_child_weight': 1,
        'objective': 'reg:squarederror',
        'nthread': 8,
        'seed': 1,
        'verbosity': 1,
    }
    
    # 训练模型
    xgb_model = xgb.train(
        xgb_params,
        dtrain,
        num_boost_round=100,
        evals=[(dtrain, 'train'), (dval, 'val')],
        verbose_eval=False
    )
    
    # 预测并计算 RMSE
    y_pred = xgb_model.predict(dval)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    results[eta] = rmse
    print(f"eta={eta}, RMSE={rmse:.6f}")

# 找出最佳 eta
best_eta = min(results, key=results.get)
print(f"\n✅ 最佳 eta: {best_eta} (RMSE={results[best_eta]:.6f})")

# 查看特征重要性（带名称）
importance = xgb_model.get_score(importance_type='weight')
print("\n特征重要性（Top 5）:")
sorted_importance = sorted(importance.items(), key=lambda x: x[1], reverse=True)[:5]
for feat, score in sorted_importance:
    print(f"  {feat}: {score}")
# Out:
# 特征数量: 14
#
# 训练 eta=0.3 的模型...
# eta=0.3, RMSE=0.029502
#
# 训练 eta=0.1 的模型...
# eta=0.1, RMSE=0.028231
#
# ✅ 最佳 eta: 0.1 (RMSE=0.028231)
#
# 特征重要性（Top 5）:
#   acceleration: 1221.0
#   horsepower: 1177.0
#   vehicle_weight: 984.0
#   engine_displacement: 631.0
#   model_year: 444.0
