# %% [markdown]
# ### In this homework, we continue using the fuel efficiency dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import  pyplot as plt
# %matplotlib  inline

# %%
# !head car_fuel_efficiency_2026.csv
# Out:
# model_year,origin,fuel_type,drivetrain,num_doors,engine_displacement,num_cylinders,horsepower,vehicle_weight,acceleration,fuel_efficiency_mpg
# 2006,Europe,Gasoline,Front-wheel drive,4,2180,6,243,3870,,31.9
# 2008,Europe,Diesel,Front-wheel drive,4,2390,6,272,4210,,31.3
# 1996,Asia,Gasoline,Front-wheel drive,5,2320,6,267,4240,17.3,27.5
# 1989,Europe,Gasoline,Front-wheel drive,4,2130,6,258,4490,18.7,28.5
# 1994,USA,Diesel,Front-wheel drive,3,2580,7,304,4510,17.5,31.0
# 2007,USA,Hybrid,Front-wheel drive,2,2290,6,266,4260,18.8,31.2
# 1992,Asia,Gasoline,Front-wheel drive,2,2270,6,250,4310,21.7,26.8
# 2005,USA,Gasoline,Front-wheel drive,4,2370,6,279,4090,17.4,30.2
# 1997,Asia,Gasoline,Rear-wheel drive,3,2330,6,251,4230,19.5,30.9

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')

# %%
df.dtypes
# Out:
# model_year               int64
# origin                     str
# fuel_type                  str
# drivetrain                 str
# num_doors                int64
# engine_displacement      int64
# num_cylinders            int64
# horsepower             float64
# vehicle_weight           int64
# acceleration           float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# model_year             0
# origin                 0
# fuel_type              0
# drivetrain             0
# num_doors              0
# engine_displacement    0
# num_cylinders          0
# horsepower             0
# vehicle_weight         0
# acceleration           0
# fuel_efficiency_mpg    0
# dtype: int64

# %%
df.describe()
# Out:
#          model_year    num_doors  engine_displacement  num_cylinders  \
# count  10000.000000  10000.00000         10000.000000   10000.000000
# mean    1999.549500      3.50400          2268.807000       6.035200
# std       14.207925      0.95209           183.447355       0.542578
# min     1975.000000      2.00000          1590.000000       4.000000
# 25%     1987.000000      3.00000          2150.000000       6.000000
# 50%     2000.000000      4.00000          2270.000000       6.000000
# 75%     2012.000000      4.00000          2390.000000       6.000000
# max     2024.000000      5.00000          3110.000000       8.000000
#
#          horsepower  vehicle_weight  acceleration  fuel_efficiency_mpg
# count  10000.000000    10000.000000  10000.000000         10000.000000
# mean     232.131100     4286.754000     18.389400            29.997700
# std       75.210419      266.212491      3.280959             2.930245
# ...

# %% [markdown]
# ### horsepower （马力） acceleration（加速度）  - 最小值0
# 下面处理这些异常值

# %%
# 查看具体有哪些0值
#df[(df['horsepower'] == 0) | (df['acceleration'] == 0)]
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 10          1978    Asia  Gasoline    All-wheel drive          3
# 12          1983     USA    Diesel  Front-wheel drive          3
# 32          1978     USA  Gasoline   Rear-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9963        1982    Asia    Hybrid  Front-wheel drive          4
# 9980        1977     USA    Hybrid  Front-wheel drive          5
# 9982        2014  Europe  Gasoline  Front-wheel drive          5
# 9983        2017  Europe  Gasoline   Rear-wheel drive          2
# 9986        1984  Europe  Gasoline  Front-wheel drive          3
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
len(df[(df['horsepower'] == 0) | (df['acceleration'] == 0)])
# Out:
# 1118

# %%
# # 用中位数填充
#median_horsepower = df['horsepower'].median()
#df['horsepower'] = df['horsepower'].replace(0, median_horsepower)
#df[df['horsepower'] == 0]
# Out:
# Empty DataFrame
# Columns: [model_year, origin, fuel_type, drivetrain, num_doors, engine_displacement, num_cylinders, horsepower, vehicle_weight, acceleration, fuel_efficiency_mpg]
# Index: []

# %%
# 使用中位数填充
#median_acceleration = df['acceleration'].median()
#df['acceleration'] = df['acceleration'].replace(0, median_acceleration)
#df[df['acceleration'] == 0]
# Out:
# Empty DataFrame
# Columns: [model_year, origin, fuel_type, drivetrain, num_doors, engine_displacement, num_cylinders, horsepower, vehicle_weight, acceleration, fuel_efficiency_mpg]
# Index: []

# %%
# 查看num_doors 值得情况
df['num_doors'].value_counts().sort_index()
# Out:
# num_doors
# 2    1647
# 3    3301
# 4    3417
# 5    1635
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# model_year               int64
# origin                     str
# fuel_type                  str
# drivetrain                 str
# num_doors                int64
# engine_displacement      int64
# num_cylinders            int64
# horsepower             float64
# vehicle_weight           int64
# acceleration           float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
df_full_train,df_test = train_test_split(df, test_size=0.2, random_state=1) 
df_train,df_val = train_test_split(df_full_train, test_size=0.25, random_state=1) 
len(df_full_train),len(df_test),len(df_train),len(df_val)
# Out:
# (8000, 2000, 6000, 2000)

# %%
df_train = df_train.reset_index(drop=True)   #将上面划分数据打乱的索引，重建索引，并删除旧索引
df_val = df_val.reset_index(drop=True) 
df_test = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.fuel_efficiency_mpg.values)
y_val = np.log1p(df_val.fuel_efficiency_mpg.values)
y_test = np.log1p(df_test.fuel_efficiency_mpg.values)

# %%
del df_train['fuel_efficiency_mpg']
del df_val['fuel_efficiency_mpg']
del df_test['fuel_efficiency_mpg']

# %%
from sklearn.feature_extraction  import DictVectorizer

# %%
train_dicts = df_train.to_dict(orient='records')
val_dicts = df_val.to_dict(orient='records')
test_dicts = df_test.to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=True) # 这里使用稀疏矩阵

# %%
X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (6000, 16)

# %%
X_val = dv.transform(val_dicts)

# %%
X_test = dv.transform(test_dicts)

# %% [markdown]
# #  Question 1

# %% [markdown]
# Let's train a decision tree regressor to predict the fuel_efficiency_mpg variable.
#
# Train a model with max_depth=1.
# Which original feature is used for splitting the data? If you use , map a one-hot feature such as back to its original column name.DictVectorizerorigin=USA
#
# model_year

# %%
from sklearn.tree import DecisionTreeRegressor  # 决策树，回归模型

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'drivetrain=Rear-wheel drive',
#        'engine_displacement', 'fuel_type=Diesel', 'fuel_type=Gasoline',
#        'fuel_type=Hybrid', 'horsepower', 'model_year', 'num_cylinders',
#        'num_doors', 'origin=Asia', 'origin=Europe', 'origin=USA',
#        'vehicle_weight'], dtype=object)

# %%
# 对于 max_depth=1 的决策树（也叫决策树桩，Decision Stump），树只有一个分裂节点，这个节点就是根节点。
# dtreg_model = DecisionTreeRegressor(max_depth=1, random_state=42)
dtreg_model = DecisionTreeRegressor(max_depth=1)

# %%
dtreg_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
feature_index = dtreg_model.tree_.feature[0]  # 根节点的分裂特征索引

# %%
feature_index
# Out:
# np.int64(9)

# %%
feature_name = dv.get_feature_names_out()[feature_index]  # 获取特征名称
feature_name
# Out:
# 'model_year'

# %% [markdown]
# # Question 2
# Train a random forest regressor with these parameters:
#
# n_estimators=10
# random_state=1
# n_jobs=-1 (optional - to make training faster)
#
# What's the RMSE of this model on the validation data?
#
# 0.059

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error    # 计算均方误差（Mean Squared Error, MSE）的评估指标函数

# %%
# 1. 创建并训练模型
rf_model = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
# 2. 在验证集上预测
y_pred = rf_model.predict(X_val)
y_pred
# Out:
# array([3.38430858, 3.40405962, 3.45762449, ..., 3.40868972, 3.43258352,
#        3.51470217], shape=(2000,))

# %%
# 3. 计算 RMSE（注意：y_val 是 log1p 转换后的值）
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.05978547291414435

# %% [markdown]
# # Question 3
# Now let's experiment with the n_estimators parameter
#
# - Try these values of this parameter: .[10, 50, 100, 150]
# - Set random_state to 1.
# - Evaluate the model on the validation dataset.
# - Which value gives the lowest validation RMSE? Consider 3 decimal places for calculating the answer.

# %%
# 存储不同 n_estimators 对应的 RMSE
# 测试的 n_estimators 值
n_values = [10, 50, 100, 150]
rmse_scores = []

for n in n_values:
    # 训练模型
    rf = RandomForestRegressor(n_estimators=n, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)
    
    # 验证集预测
    y_pred = rf.predict(X_val)
    
    # 计算 RMSE
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    rmse_scores.append(rmse)
    
    print(f"n_estimators={n:3d}, RMSE={rmse:.3f}")
# Out:
# n_estimators= 10, RMSE=0.060
# n_estimators= 50, RMSE=0.058
# n_estimators=100, RMSE=0.058
# n_estimators=150, RMSE=0.058

# %% [markdown]
# # Question 4
# Let's select the best max_depth:
#
# - Try different values of max_depth: [10, 15, 20, 25]
# - For each of these values,
# try different values of n_estimators from n_estimators[10, 50, 100, 150]
# calculate the mean RMSE
# - Fix the random seed: random_state=1
# What's the best max_depth, using the mean RMSE?
#
# 10

# %%
max_depth_values = [10, 15, 20, 25]
n_estimators_range = [10, 50, 100, 150]
for max_depth in max_depth_values:
    rmse_list = []
    
    for n in n_estimators_range:
        rf = RandomForestRegressor(
            n_estimators=n,
            max_depth=max_depth,
            random_state=1,
            n_jobs=-1
        )
        rf.fit(X_train, y_train)
        
        # 验证集预测
        y_pred = rf.predict(X_val)
        
        # 计算 RMSE
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        rmse_list.append(rmse)
    
    # 计算平均 RMSE
    mean_rmse = np.mean(rmse_list)

    print(f"max_depth={max_depth:2d}, 平均 RMSE={mean_rmse:.6f}")
# Out:
# max_depth=10, 平均 RMSE=0.057429
# max_depth=15, 平均 RMSE=0.058164
# max_depth=20, 平均 RMSE=0.058287
# max_depth=25, 平均 RMSE=0.058291

# %% [markdown]
# # Question 5
# We can extract feature importance information from tree-based models.
#
# At each step of the decision tree learning algorithm, it finds the best split. When doing it, we can calculate "gain" - the reduction in impurity before and after the split. This gain is quite useful in understanding what are the important features for tree-based models.
#
# In Scikit-Learn, tree-based models contain this information in the feature_importances_ field.
#
# For this homework question, we'll find the most important feature:
#
# Train the model with these parameters:
# n_estimators=10,
# max_depth=20,
# random_state=1,
# n_jobs=-1 (optional)
# Get the feature importance information from this model
# What's the most important feature (among these 4)?
#
# vehicle_weight

# %%
# 1. 训练模型（使用指定参数）
rf_model = RandomForestRegressor(
    n_estimators=10,
    max_depth=20,
    random_state=1,
    n_jobs=-1
)
rf_model.fit(X_train, y_train)

# 2. 获取特征重要性
feature_importances = rf_model.feature_importances_
feature_names = dv.get_feature_names_out()

# 3. 创建特征重要性 DataFrame 并排序
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importances
})
importance_df = importance_df.sort_values('importance', ascending=False)

# 4. 显示所有特征的重要性
print("所有特征的重要性（从高到低）:")
print(importance_df)

# 5. 只显示题目给出的4个特征
print("\n题目中的4个特征重要性:")
target_features = ['vehicle_weight', 'horsepower', 'acceleration', 'engine_displacement']
for feature in target_features:
    importance = importance_df[importance_df['feature'] == feature]['importance'].values[0]
    print(f"{feature:20s}: {importance:.6f}")

# 6. 找出最重要的特征
most_important = importance_df.iloc[0]['feature']
most_importance = importance_df.iloc[0]['importance']
print(f"\n 最重要的特征: {most_important} (重要性: {most_importance:.6f})")
# Out:
# 所有特征的重要性（从高到低）:
#                          feature  importance
# 9                     model_year    0.296583
# 15                vehicle_weight    0.208354
# 6             fuel_type=Gasoline    0.154173
# 8                     horsepower    0.076053
# 4            engine_displacement    0.065703
# 0                   acceleration    0.057725
# 14                    origin=USA    0.042699
# 2   drivetrain=Front-wheel drive    0.021658
# 11                     num_doors    0.018790
# 7               fuel_type=Hybrid    0.016516
# 5               fuel_type=Diesel    0.011846
# 1     drivetrain=All-wheel drive    0.007308
# 12                   origin=Asia    0.007096
# 10                 num_cylinders    0.007084
# 3    drivetrain=Rear-wheel drive    0.004988
# 13                 origin=Europe    0.003423
#
# 题目中的4个特征重要性:
# vehicle_weight      : 0.208354
# horsepower          : 0.076053
# acceleration        : 0.057725
# engine_displacement : 0.065703
#
# ...

# %% [markdown]
# # Question 6
# Now let's train an XGBoost model! For this question, we'll tune the eta parameter:
#
# - Install XGBoost
# - Create DMatrix for train and validation
# - Create a watchlist
# - Train a model with these parameters for 100 rounds:
# xgb_params = {
#     'eta': 0.3,
#     'max_depth': 6,
#     'min_child_weight': 1,
#
#     'objective': 'reg:squarederror',
#     'nthread': 8,
#
#     'seed': 1,
#     'verbosity': 1,
# }
# Now change eta from 0.3 to 0.1.
#
# Which eta leads to the best RMSE score on the validation dataset?
#
# 0.1

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

features = dv.get_feature_names_out().tolist()
print(f"特征数量: {len(features)}")

# 创建 DMatrix（指定 feature_names）
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# 测试不同的 eta
eta_values = [0.3, 0.1]
results = {}

for eta in eta_values:
    print(f"\n训练 eta={eta} 的模型...")
    
    xgb_params = {
        'eta': eta,
        'max_depth': 6,
        'min_child_weight': 1,
        'objective': 'reg:squarederror',
        'nthread': 8,
        'seed': 1,
        'verbosity': 1,
    }
    
    # 训练模型
    xgb_model = xgb.train(
        xgb_params,
        dtrain,
        num_boost_round=100,
        evals=[(dtrain, 'train'), (dval, 'val')],
        verbose_eval=False
    )
    
    # 预测并计算 RMSE
    y_pred = xgb_model.predict(dval)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    results[eta] = rmse
    print(f"eta={eta}, RMSE={rmse:.6f}")

# 找出最佳 eta
best_eta = min(results, key=results.get)
print(f"\n✅ 最佳 eta: {best_eta} (RMSE={results[best_eta]:.6f})")

# 查看特征重要性（带名称）
importance = xgb_model.get_score(importance_type='weight')
print("\n特征重要性（Top 5）:")
sorted_importance = sorted(importance.items(), key=lambda x: x[1], reverse=True)[:5]
for feat, score in sorted_importance:
    print(f"  {feat}: {score}")
# Out:
# 特征数量: 16
#
# 训练 eta=0.3 的模型...
# eta=0.3, RMSE=0.060298
#
# 训练 eta=0.1 的模型...
# eta=0.1, RMSE=0.056471
#
# ✅ 最佳 eta: 0.1 (RMSE=0.056471)
#
# 特征重要性（Top 5）:
#   acceleration: 803.0
#   engine_displacement: 785.0
#   vehicle_weight: 775.0
#   horsepower: 707.0
#   model_year: 702.0
